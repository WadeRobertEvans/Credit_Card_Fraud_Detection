# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# **Author: Wade Evans**
# Reference: https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# **Content**
#
# The datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data.
#
# Features **V1, V2, ... V28** are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'.
#
# Feature **'Time'** contains the seconds elapsed between each transaction and the first transaction in the dataset.
#
# The feature **'Amount'** is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
# Feature **'Class'** is the response variable and it takes value **1 in case of fraud and 0 otherwise**.
#
# **Inspiration**
#
# Identify fraudulent credit card transactions.
#
# Given the class imbalance ratio, we recommend measuring the accuracy using the Area Under the Precision-Recall Curve (AUPRC). Confusion matrix accuracy is not meaningful for unbalanced classification.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df['Class'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %% [markdown]
# ## EDA

# %%
# Check for null (NaN) values

df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Check for null (NaN) values

df.isnull().values.any()
# Out:
# False

# %%
# Check unique values in feature 'Class'

df['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Check number of unique values in feature 'Class'

df['Class'].nunique()
# Out:
# 2

# %%
# Check the number of 'Class' feature values equal to 0 for all other features

df[df['Class']==0].count()
# Out:
# Time      284315
# V1        284315
# V2        284315
# V3        284315
# V4        284315
# V5        284315
# V6        284315
# V7        284315
# V8        284315
# V9        284315
# V10       284315
# V11       284315
# V12       284315
# V13       284315
# V14       284315
# V15       284315
# V16       284315
# V17       284315
# V18       284315
# V19       284315
# V20       284315
# V21       284315
# V22       284315
# V23       284315
# V24       284315
# V25       284315
# V26       284315
# V27       284315
# V28       284315
# Amount    284315
# Class     284315
# dtype: int64

# %%
# Check the number of 'Class' feature values equal to 1 for all other features

df[df['Class']==1].count()
# Out:
# Time      492
# V1        492
# V2        492
# V3        492
# V4        492
# V5        492
# V6        492
# V7        492
# V8        492
# V9        492
# V10       492
# V11       492
# V12       492
# V13       492
# V14       492
# V15       492
# V16       492
# V17       492
# V18       492
# V19       492
# V20       492
# V21       492
# V22       492
# V23       492
# V24       492
# V25       492
# V26       492
# V27       492
# V28       492
# Amount    492
# Class     492
# dtype: int64

# %%
# Check the number of 0 and 1 'Class' feature values
    # 0 = not fraud
    # 1 = fraud

df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Show the feature column names

df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# Plot confirms the data is very unbalanced

sns.displot(data=df,x='Class',hue='Class')
plt.xticks(ticks=[0,1])
# Out:
# ([<matplotlib.axis.XTick at 0x2cf174d6370>,
# ...
#  [Text(-0.2, 0, '−0.2'), Text(0.0, 0, '0.0')])

# %% [markdown]
# We need to analyze more amount of information from the transaction data.
# How different are the amount of monies used in different transaction classes?

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='Class',y='Amount')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Amount'>

# %%
sns.boxplot(data=df,x='Class',y='Time')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Time'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='Time',y='Amount',hue='Class')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Amount'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df[df['Class']==0],x='Time',y='Amount')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Amount'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df[df['Class']==1],x='Time',y='Amount')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Amount'>

# %%
sns.displot(data=df[df['Class']==0],x='Amount',height=6)

# %%
sns.displot(data=df[df['Class']==1],x='Amount',height=6)

# %%
df[df['Class']==0]['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df[df['Class']==1]['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data=df.corr(),cmap='jet',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model prediction - Logistic regression

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Normalising the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Creating the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Predictions

# %%
predictions = logmodel.predict(X_test)

# %% [markdown]
# ### Evaluating model performance

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[85295    12]
#  [   63    73]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.86      0.54      0.66       136
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.77      0.83     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### C=0.1 (default = 1)

# %% [markdown]
# **Smaller values of C represent stronger regularisation**

# %%
logmodel = LogisticRegression(C=0.1)
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[85301     6]
#  [   97    39]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.87      0.29      0.43       136
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.64      0.72     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### C=5 (default = 1)

# %%
logmodel = LogisticRegression(C=5)
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[85294    13]
#  [   58    78]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.86      0.57      0.69       136
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.79      0.84     85443
# weighted avg       1.00      1.00      1.00     85443
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### C=10 (default = 1)

# %%
logmodel = LogisticRegression(C=10)
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[85294    13]
#  [   56    80]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.86      0.59      0.70       136
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.79      0.85     85443
# weighted avg       1.00      1.00      1.00     85443
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Scale (vs normalise)

# %%
A = df.drop('Class',axis=1)
b = df['Class']

# %%
A_train, A_test, b_train, b_test = train_test_split(A, b, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
A_train = scaler.fit_transform(A_train)

# %%
A_test = scaler.transform(A_test)

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(A_train,b_train)
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(A_test)

# %%
print(confusion_matrix(b_test,predictions))
print('\n')
print(classification_report(b_test,predictions))
# Out:
# [[85295    12]
#  [   50    86]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.88      0.63      0.74       136
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.82      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### C=0.1 (default = 1) - Scaled

# %%
logmodel = LogisticRegression(C=0.1)
logmodel.fit(A_train,b_train)
predictions = logmodel.predict(A_test)
print(confusion_matrix(b_test,predictions))
print('\n')
print(classification_report(b_test,predictions))
# Out:
# [[85295    12]
#  [   51    85]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.88      0.62      0.73       136
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.81      0.86     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### C=5 (default = 1) - Scaled

# %%
logmodel = LogisticRegression(C=5)
logmodel.fit(A_train,b_train)
predictions = logmodel.predict(A_test)
print(confusion_matrix(b_test,predictions))
print('\n')
print(classification_report(b_test,predictions))
# Out:
# [[85295    12]
#  [   50    86]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.88      0.63      0.74       136
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.82      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### C=10 (default = 1) - Scaled

# %%
logmodel = LogisticRegression(C=10)
logmodel.fit(A_train,b_train)
predictions = logmodel.predict(A_test)
print(confusion_matrix(b_test,predictions))
print('\n')
print(classification_report(b_test,predictions))
# Out:
# [[85295    12]
#  [   50    86]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.88      0.63      0.74       136
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.82      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ## Model prediction - KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(A_train,b_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
knn_predictions = knn.predict(A_test)

# %%
print(confusion_matrix(b_test,knn_predictions))
print('\n')
print(classification_report(b_test,knn_predictions))
# Out:
# [[85286    21]
#  [   25   111]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.84      0.82      0.83       136
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.91      0.91     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### Choosing a K value

# %%
error_rate = []

for i in range(1,11):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(A_train,b_train)
    knn_predictions = knn.predict(A_test)
    error_rate.append(np.mean(knn_predictions != b_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,11),error_rate,color='blue',linestyle='dashed',marker='o', markerfacecolor='red',markersize=10)
plt.title('Error Rate vs K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ### K = 3

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(A_train,b_train)
knn_predictions = knn.predict(A_test)
print(confusion_matrix(b_test,knn_predictions))
print('\n')
print(classification_report(b_test,knn_predictions))
# Out:
# [[85298     9]
#  [   29   107]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.92      0.79      0.85       136
#
#     accuracy                           1.00     85443
#    macro avg       0.96      0.89      0.92     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# **ROC - AUC Curve**

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
score = roc_auc_score(b_test, knn_predictions)

# %%
print('ROC-AUC Score is:-', score)
# Out:
# ROC-AUC Score is:- 0.8933296022876543

# %%
# fpr = false positive rate (x-axis) = 1 - specificity = fp / (fp + tn) 
# tpr = true positive rate (y-axis) = sensitivity = tp / (tp + fn)

fpr, tpr, thresholds = roc_curve(b_test, knn_predictions)

# %%
plt.plot(fpr, tpr, label='ROC Curve (area=%0.2f)' % score)
plt.plot([0,1], [0,1], 'k--')
plt.legend()
plt.show()
